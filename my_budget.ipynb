# %%
import pandas as pd
import numpy as np
import os 
import sys
import time
from pathlib import Path
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns',None)

# %%
dump = pd.read_excel('sample.xlsx')
print(dump.shape)
dump.head(1)
# Out:
# (517, 30)
#   Zone Issuing Region Branch Name Market Type  Branch Code Group Class  \
# 0  NaN            NaN         NaN         NaN          NaN         NaN
#
#   Agent Name Agent Code SM Code SM Name IMD Code IMD Name IMDRefCode System  \
# 0        NaN        NaN     NaN     NaN      NaN      NaN        NaN    NaN
#
#   Actual Biz Type Year Quarter Product Category Month LOB Flag  \
# 0             NaN  NaN     NaN              NaN   NaN      NaN
#
#   FinalSubChannel Product SubCategory  Relationship Name  \
# 0             NaN                 NaN                NaN
#
#    EXT_new_business_type EXT_subchannel EXT_relationship EXT_markettype  \
# 0                    NaN            NaN              NaN            NaN
#
#   RelationshipName_PR  Policy Count    Premium
# 0                 NaN        925492  41616.907

# %%
dump.drop(0,axis=0, inplace = True)
dump.head(2)
# Out:
#              Zone    Issuing Region       Branch Name     Market Type  \
# 1  CORPORATE ZONE  CORPORATE REGION  CORPORATE OFFICE  DIRECT MARKETS
# 2  CORPORATE ZONE  CORPORATE REGION  CORPORATE OFFICE  DIRECT MARKETS
#
#    Branch Code           Group Class              Agent Name Agent Code  \
# 1       9201.0  ALL COMMERCIAL LINES                  DIRECT     DIRECT
# 2       9201.0  ALL COMMERCIAL LINES  PRATIBHA RAKESH WANKAR   15A28995
#
#     SM Code          SM Name IMD Code                IMD Name  \
# 1  50019582  ANIL DYVANPELLI       39       DIRECT-VIRTUAL RM
# 2  50019582  ANIL DYVANPELLI   362878  RAKESH SHRIHARI WANKAR
#
#               IMDRefCode System Actual Biz Type       Year Quarter  \
# 1  18P02796-000039-92021    ICM  FRESH BUSINESS  2020-2021      Q4
# 2  15A28995-362878-92021    ICM  FRESH BUSINESS  2020-2021      Q4
#
#   Product Category Month LOB Flag FinalSubChannel Product SubCategory  \
# ...

# %%
dump2 = dump.drop([dump.index[0]],inplace=False)
dump2.head(2)
# Out:
#              Zone    Issuing Region       Branch Name     Market Type  \
# 2  CORPORATE ZONE  CORPORATE REGION  CORPORATE OFFICE  DIRECT MARKETS
# 3  CORPORATE ZONE  CORPORATE REGION  CORPORATE OFFICE  DIRECT MARKETS
#
#    Branch Code           Group Class              Agent Name Agent Code  \
# 2       9201.0  ALL COMMERCIAL LINES  PRATIBHA RAKESH WANKAR   15A28995
# 3       9201.0            ALL HEALTH     ABHIJITH EDATT RAVI   17A36941
#
#     SM Code          SM Name IMD Code                IMD Name  \
# 2  50019582  ANIL DYVANPELLI   362878  RAKESH SHRIHARI WANKAR
# 3  50019582  ANIL DYVANPELLI   368891           SANTOSH KUMAR
#
#               IMDRefCode System Actual Biz Type       Year Quarter  \
# 2  15A28995-362878-92021    ICM  FRESH BUSINESS  2020-2021      Q4
# 3  17A36941-368891-70711    ICM  FRESH BUSINESS  2020-2021      Q4
#
#       Product Category Month LOB Flag FinalSubChannel Product SubCategory  \
# ...

# %%
dump=dump.loc[dump.Year=='2020-2021']
print(dump.shape)
dump.head(2)
# Out:
# (516, 30)
#              Zone    Issuing Region       Branch Name     Market Type  \
# 1  CORPORATE ZONE  CORPORATE REGION  CORPORATE OFFICE  DIRECT MARKETS
# 2  CORPORATE ZONE  CORPORATE REGION  CORPORATE OFFICE  DIRECT MARKETS
#
#    Branch Code           Group Class              Agent Name Agent Code  \
# 1       9201.0  ALL COMMERCIAL LINES                  DIRECT     DIRECT
# 2       9201.0  ALL COMMERCIAL LINES  PRATIBHA RAKESH WANKAR   15A28995
#
#     SM Code          SM Name IMD Code                IMD Name  \
# 1  50019582  ANIL DYVANPELLI       39       DIRECT-VIRTUAL RM
# 2  50019582  ANIL DYVANPELLI   362878  RAKESH SHRIHARI WANKAR
#
#               IMDRefCode System Actual Biz Type       Year Quarter  \
# 1  18P02796-000039-92021    ICM  FRESH BUSINESS  2020-2021      Q4
# 2  15A28995-362878-92021    ICM  FRESH BUSINESS  2020-2021      Q4
#
#   Product Category Month LOB Flag FinalSubChannel Product SubCategory  \
# ...
